# %%
import pandas as pd

# %%
my_dataset = pd.read_csv("country_level_data_0.csv")
my_dataset
# Out:
#     region_id  country_name           gdp  \
# 0         LCN         Aruba  35563.312500
# 1         SAS   Afghanistan   2057.062256
# 2         SSF        Angola   8036.690430
# 3         ECS       Albania  13724.058590
# 4         ECS       Andorra  43711.800780
# ..        ...           ...           ...
# 212       ECS        Kosovo   9723.561523
# 213       MEA   Yemen, Rep.   8269.671875
# 214       SSF  South Africa  12666.607420
# 215       SSF        Zambia   3201.289307
# 216       SSF      Zimbabwe   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ...

# %%
# Below code gives percentage of null in every column
null_percentage = my_dataset.isnull().sum()/my_dataset.shape[0]*100
null_percentage
# Out:
# region_id                                                                                 0.000000
# country_name                                                                              0.460829
# gdp                                                                                       0.460829
# composition_food_organic_waste_percent                                                   18.894009
# composition_glass_percent                                                                21.198157
# composition_metal_percent                                                                21.658986
# composition_other_percent                                                                19.354839
# composition_paper_cardboard_percent                                                      18.894009
# composition_plastic_percent                                                              19.354839
# ...

# %%
col_to_drop = null_percentage[null_percentage>40].keys()
len(col_to_drop)
# Out:
# 34

# %%
smaller_dataset = my_dataset.drop(col_to_drop, axis=1)

# %%
smaller_dataset
# Out:
#     region_id  country_name           gdp  \
# 0         LCN         Aruba  35563.312500
# 1         SAS   Afghanistan   2057.062256
# 2         SSF        Angola   8036.690430
# 3         ECS       Albania  13724.058590
# 4         ECS       Andorra  43711.800780
# ..        ...           ...           ...
# 212       ECS        Kosovo   9723.561523
# 213       MEA   Yemen, Rep.   8269.671875
# 214       SSF  South Africa  12666.607420
# 215       SSF        Zambia   3201.289307
# 216       SSF      Zimbabwe   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ...

# %%
# Out:
# Empty DataFrame
# ...

# %%
# Imputation for Cleaning
data = smaller_dataset.copy()
def mode_imputition(i):

    data[i] = data[i].fillna(data[i].mode()[0])
    return data[i]

for i in data.select_dtypes(include = "object").columns:
    mode_imputition(i)

################################################################################

def median_imputition(i):

    data[i] = data[i].fillna(data[i].median())
    return data[i]

for i in data.select_dtypes(include = "number").columns:
    median_imputition(i)

# %%
data
# Out:
#     region_id  country_name           gdp  \
# 0         LCN         Aruba  35563.312500
# 1         SAS   Afghanistan   2057.062256
# 2         SSF        Angola   8036.690430
# 3         ECS       Albania  13724.058590
# 4         ECS       Andorra  43711.800780
# ..        ...           ...           ...
# 212       ECS        Kosovo   9723.561523
# 213       MEA   Yemen, Rep.   8269.671875
# 214       SSF  South Africa  12666.607420
# 215       SSF        Zambia   3201.289307
# 216       SSF      Zimbabwe   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                 43.200000                   4.000000
# 1                                 43.200000                   4.000000
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ...

# %%
my_dataset
# Out:
#     region_id  country_name           gdp  \
# 0         LCN         Aruba  35563.312500
# 1         SAS   Afghanistan   2057.062256
# 2         SSF        Angola   8036.690430
# 3         ECS       Albania  13724.058590
# 4         ECS       Andorra  43711.800780
# ..        ...           ...           ...
# 212       ECS        Kosovo   9723.561523
# 213       MEA   Yemen, Rep.   8269.671875
# 214       SSF  South Africa  12666.607420
# 215       SSF        Zambia   3201.289307
# 216       SSF      Zimbabwe   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                 43.200000                   4.000000
# 1                                 43.200000                   4.000000
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ...

# %%
data.to_csv("Cleaned_Global_pollution.csv", index=False)

# %%
import pandas as pd

# %%
my_dataset = pd.read_csv("Cleaned_Global_pollution.csv")
